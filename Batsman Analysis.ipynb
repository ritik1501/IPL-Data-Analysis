# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('deliveries.csv')
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df.shape
# Out:
# (150460, 21)

# %%
df.describe()
# Out:
#             match_id         inning           over           ball  \
# count  150460.000000  150460.000000  150460.000000  150460.000000
# mean      318.281317       1.482188      10.142649       3.616483
# std       182.955531       0.501768       5.674338       1.807698
# min         1.000000       1.000000       1.000000       1.000000
# 25%       161.000000       1.000000       5.000000       2.000000
# 50%       319.000000       1.000000      10.000000       4.000000
# 75%       476.000000       2.000000      15.000000       5.000000
# max       636.000000       4.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  150460.000000  150460.000000  150460.000000  150460.000000
# mean        0.000538       0.037498       0.004885       0.022232
# std         0.023196       0.257398       0.114234       0.200104
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
batsman = df['batsman']=='RG Sharma'
df_rohit = df[batsman]
print(df_rohit.shape)
df_rohit
# Out:
# (3274, 21)
#         match_id  inning    batting_team            bowling_team  over  ball  \
# 275            2       1  Mumbai Indians  Rising Pune Supergiant     5     3
# 276            2       1  Mumbai Indians  Rising Pune Supergiant     5     4
# 278            2       1  Mumbai Indians  Rising Pune Supergiant     5     6
# 279            2       1  Mumbai Indians  Rising Pune Supergiant     6     1
# 285            2       1  Mumbai Indians  Rising Pune Supergiant     7     1
# ...          ...     ...             ...                     ...   ...   ...
# 148781       630       1  Mumbai Indians           Gujarat Lions     3     5
# 148783       630       1  Mumbai Indians           Gujarat Lions     4     1
# 148785       630       1  Mumbai Indians           Gujarat Lions     4     3
# 148786       630       1  Mumbai Indians           Gujarat Lions     4     4
# 148787       630       1  Mumbai Indians           Gujarat Lions     4     5
#
# ...

# %%
df_rohit['dismissal_kind'].value_counts()
# Out:
# caught               83
# bowled               20
# run out              15
# lbw                   8
# caught and bowled     6
# stumped               3
# Name: dismissal_kind, dtype: int64

# %%
df_rohit['dismissal_kind'].value_counts().plot.pie()

# %%
fours = len(df_rohit[df_rohit['batsman_runs']==4])
# Out:
# 354

# %%
sixes = len(df_rohit[df_rohit['batsman_runs']==6])
# Out:
# 173

# %%
def runs(df, run):
    return len(df_rohit[df_rohit['batsman_runs']==run])*run

# %%
print("Singles : ",runs(df_rohit,1))
print("Doubles : ",runs(df_rohit,2))
print("Triples : ",runs(df_rohit,3))
print("Fours : ",runs(df_rohit,4))
print("Fives : ",runs(df_rohit,5))
print("Sixes : ",runs(df_rohit,6))
# Out:
# Singles :  1379
# Doubles :  354
# Triples :  15
# Fours :  1416
# Fives :  5
# Sixes :  1038

# %%
slices = [1379,354,15,1416,5,1038]
labels = [1,2,3,4,5,6]
explode = [0,0,0,0.1,0,0]
plt.pie(slices, labels=labels,autopct="%1.1f%%", explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x2392079c100>,
# ...
#  [Text(0.5665145293510186, 0.9429004656029151, '1'),
#   Text(-0.7522948947921239, 0.802528747939728, '2'),
#   Text(-0.9422652851712017, 0.5675703765712531, '3'),
#   Text(-1.0375087370924225, -0.6029723214683133, '4'),
#   Text(0.018481202471977144, -1.099844736840246, '5'),
#   Text(0.7857627860108979, -0.7697901299187929, '6')],
#  [Text(0.3090079251005556, 0.5143093448743172, '32.8%'),
#   Text(-0.41034266988661294, 0.43774295342166974, '8.4%'),
#   Text(-0.5139628828206554, 0.309583841766138, '0.4%'),
#   Text(-0.6052134299705797, -0.35173385418984937, '33.7%'),
#   Text(0.010080655893805713, -0.5999153110037705, '0.1%'),
#   Text(0.42859788327867154, -0.41988552541025065, '24.7%')])
